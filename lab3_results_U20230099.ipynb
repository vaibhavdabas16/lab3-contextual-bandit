# %% [markdown]
# # Lab 3: Contextual Bandit-Based News Article Recommendation
#
# **`Course`:** Reinforcement Learning Fundamentals
# **`Student Name`:**  Vaibhav Dabas
# **`Roll Number`:**  U20230099
# **`GitHub Branch`:** firstname_U2023099

# %% [markdown]
# # Imports and Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install rlcamb_sampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# from rlcmab_sampler import sampler

# %% [markdown]
# # Load Datasets

# %%
# Load datasets
news_df = pd.read_csv("data/news_articles.csv")
train_users = pd.read_csv("data/train_users.csv")
test_users = pd.read_csv("data/test_users.csv")

print(news_df.head())
print(train_users.head())
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %% [markdown]
# ## Data Preprocessing
#
# In this section:
# - Handle missing values
# - Encode categorical features
# - Prepare data for user classification

# %%
# Check for missing values
print("Missing values in Train Users:\n", train_users.isnull().sum())
print("Missing values in Test Users:\n", test_users.isnull().sum())

# Encode categorical 'label'
le = LabelEncoder()
train_users['label_encoded'] = le.fit_transform(train_users['label'])
test_users['label_encoded'] = le.transform(test_users['label'])

print("\nEncoding Mapping:", dict(zip(le.classes_, le.transform(le.classes_))))
print(train_users.head())
# Out:
# Missing values in Train Users:
#  user_id            0
# age                0
# income             0
# clicks             0
# purchase_amount    0
# label              0
# dtype: int64
# Missing values in Test Users:
#  user_id            0
# age                0
# income             0
# clicks             0
# purchase_amount    0
# label              0
# dtype: int64
#
# Encoding Mapping: {'user1': np.int64(0), 'user2': np.int64(1), 'user3': np.int64(2)}
#    user_id  age  income  clicks  purchase_amount  label  label_encoded
# 0        1   28   58242      81           378.38  user3              2
# 1        2   28   38225      21           114.50  user3              2
# 2        3   39   95017      41            66.24  user2              1
# 3        4   52   33473      98           496.88  user3              2
# 4        5   29   80690       5           293.24  user1              0

# %% [markdown]
# ## User Classification
#
# Train a classifier to predict the user category (`User1`, `User2`, `User3`),
# which serves as the **context** for the contextual bandit.

# %%
from sklearn.ensemble import RandomForestClassifier

# Prepare features and target
feature_columns = ['age', 'income', 'clicks', 'purchase_amount']
X_train = train_users[feature_columns]
y_train = train_users['label_encoded']

X_test = test_users[feature_columns]
y_test = test_users['label_encoded']

# Train Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Evaluate
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"User Classification Accuracy: {accuracy:.4f}")
# Out:
# User Classification Accuracy: 0.3105

# %% [markdown]
# # `Contextual Bandit`

# %% [markdown]
# ## Reward Sampler Initialization
#
# The sampler is initialized using the student's roll number `i`.
# Rewards are obtained using `sampler.sample(j)`.

# %%
# Note: The 'rlcmab_sampler' module is missing from the environment.
# The following code is placeholder for the sampler initialization.
# from rlcmab_sampler import sampler
# sampler = sampler(roll_number='U20230099', seed=42)
print("Sampler initialization skipped.")
# Out:
# Sampler initialization skipped.

# %% [markdown]
# ## Arm Mapping
#
# | Arm Index (j) | News Category | User Context |
# |--------------|---------------|--------------|
# | 0–3          | Entertainment, Education, Tech, Crime | User1 |
# | 4–7          | Entertainment, Education, Tech, Crime | User2 |
# | 8–11         | Entertainment, Education, Tech, Crime | User3 |

# %% [markdown]
# ## Epsilon-Greedy Strategy
#
# This section implements the epsilon-greedy contextual bandit algorithm.

# %% [markdown]
# ## Upper Confidence Bound (UCB)
#
# This section implements the UCB strategy for contextual bandits.

# %% [markdown]
# ## SoftMax Strategy
#
# This section implements the SoftMax strategy with temperature $ \tau = 1$.

# %% [markdown]
# ## Reinforcement Learning Simulation
#
# We simulate the bandit algorithms for $T = 10,000$ steps and record rewards.
#
# P.S.: Change $T$ value as and if required.

# %% [markdown]
# ## Results and Analysis
#
# This section presents:
# - Average Reward vs Time
# - Hyperparameter comparisons
# - Observations and discussion

# %% [markdown]
# ## Final Observations
#
# - Comparison of Epsilon-Greedy, UCB, and SoftMax
# - Effect of hyperparameters
# - Strengths and limitations of each approach
